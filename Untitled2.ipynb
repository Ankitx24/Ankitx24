# %% [markdown]
# <a href="https://colab.research.google.com/github/Ankitx24/Ankitx24/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 21
cgpa = 8.67
city = "Delhi"
is_admin = False


print(type(age))
print(type(cgpa))
print(type(city))
print(type(is_admin))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
name = "Aman"
age = 20
city = "Delhi"
id = "8393829"
phone_number = "xxx9383992"

print(f"""
------- STUDENT ID CARD ------
Name = {name}
Age = {age}
City = {city}
StudentID = {id}
Phone_No = {phone_number}
------------------------------
""")
# Out:
#
# ------- STUDENT ID CARD ------
# Name = Aman
# Age = 20
# City = Delhi
# StudentID = 8393829
# Phone_No = xxx9383992
# ------------------------------
